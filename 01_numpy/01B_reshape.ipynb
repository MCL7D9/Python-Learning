# %%
import numpy as np

# %%
a= np.arange(6)
print(a)
# Out:
# [0 1 2 3 4 5]

# %%
b = np.reshape(a, (3,2))
print(b)
# Out:
# [[0 1]
#  [2 3]
#  [4 5]]

# %%
c = np.array([[1,2],[3,4],[5,6]])
print(c)
# Out:
# [[1 2]
#  [3 4]
#  [5 6]]

# %%
d = np.transpose(c)
print(d)
# Out:
# [[1 3 5]
#  [2 4 6]]

# %%
print(np.sum(c, axis=0))
# Out:
# [ 9 12]

# %%
print(np.sum(d, axis=1))
# Out:
# [ 9 12]
