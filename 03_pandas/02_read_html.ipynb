# %%
# Need to sudo pip install lxml, then restart kernel

# %%
import pandas as pd

# %%
df = pd.read_html('http://loksir.com')

# %%
df

# %%
type(df)

# %%
len(df)

# %%
df[0]

# %%
type(df[0])

# %%
df[1]

# %%
df[2]

# %%
df[3]

# %%
df[4]

# %%
# recommend to use BeautifulSoup to scrape html
