# %%
import pandas as pd

# %%
# create series from list
lst = ['Apple','Orange','Apple', 'Kiwi','Pear','Orange','Banana','Kiwi']
sr = pd.Series(lst)

# %%
sr
# Out:
# 0     Apple
# 1    Orange
# 2     Apple
# 3      Kiwi
# 4      Pear
# 5    Orange
# 6    Banana
# 7      Kiwi
# dtype: object

# %%
# python set - no duplicate, unordered
x = {'Apple','Orange','Apple', 'Kiwi','Pear','Orange','Banana','Kiwi'}
print(x)
# Out:
# {'Apple', 'Kiwi', 'Banana', 'Pear', 'Orange'}

# %%
from google.colab import drive
drive.mount('/content/Mydrive')
# Out:
# Mounted at /content/Mydrive

# %%
df = pd.read_csv('examscore_dataset.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-21-d937e732e263> in <module>()
# ----> 1 df = pd.read_csv('examscore_dataset.csv')
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
df.drop_duplicates(subset="country of birth", keep = 'first', inplace = True)  # direct modfiy our dataframe
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-0da1a5adc3d8> in <module>()
# ----> 1 df.drop_duplicates(subset="country of birth", keep = 'first', inplace = True)  # direct modfiy our dataframe
#
# NameError: name 'df' is not defined

# %%
df.head(10)

# %%
df = pd.read_csv('examscore_dataset.csv')
df2 = df.drop_duplicates(subset="country of birth", keep = 'first', inplace = False) # return a new dataframe
df2.head(10)
