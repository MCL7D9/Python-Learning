# %%
import pandas as pd

# %%
# create a series from single value

# %%
sr = pd.Series('Kobocheung') # use shift-tab to view code-hint, shift-tab 4 times to view docstring

# %%
type(sr)
# Out:
# pandas.core.series.Series

# %%
sr
# Out:
# 0    Kobocheung
# dtype: object

# %%
sr = pd.Series('Kobocheung', index = range(3))

# %%
sr
# Out:
# 0    Kobcccheung
# 1    Kobcccheung
# 2    Kobcccheung
# dtype: object

# %%
# create a series from list

# %%
lst = ['Apple','Orange','Kiwi','Pear','Banana',"ttt",'ok',121]
sr = pd.Series(lst)
print(lst)
# Out:
# ['Apple', 'Orange', 'Kiwi', 'Pear', 'Banana', 'ttt', 'ok', 121]

# %%
sr
# Out:
# 0     Apple
# 1    Orange
# 2      Kiwi
# 3      Pear
# 4    Banana
# 5       ttt
# 6        ok
# 7       121
# dtype: object

# %%
# create a series from dictionary

# %%
dict={'Apple':'red','Orange':'orange','Kiwi':'green','Pear':'yellowish','Banana':'yellow'}
sr = pd.Series(dict)

# %%
sr
# Out:
# Apple           red
# Orange       orange
# Kiwi          green
# Pear      yellowish
# Banana       yellow
# dtype: object
