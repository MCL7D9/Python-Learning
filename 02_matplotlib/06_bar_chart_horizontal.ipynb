# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
x = ['apple','banana','carrot']
y = [10,22,34]
plt.barh (x,y)
plt.title("Bar chart") 
plt.show()

# %%
# Change x-axis tick label

# %%
plt.barh(x,y)
plt.title("Bar chart") 
plt.xticks([10,20,30,40], ['0-10','10-20','20-30','over 30'], fontsize=10, rotation=45)
plt.show()
