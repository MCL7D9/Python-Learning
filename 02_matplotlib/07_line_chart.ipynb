# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
x = ['a','b','c','d','e']
y = [1,2,3,4,5]

# %%
plt.plot (x,y)
plt.title("Bar chart") 
plt.show()

# %%
x2 = np.arange(5)
y2 = [1,2,3,4,5]
plt.plot(x2,y2)
plt.title("Bar chart")
plt.show()

# %%
x3 = [1,2,3,4,5]
y3 = [1,4,9,16,25]
plt.plot(x3,y3)
plt.title("Bar chart")
plt.show()
