# %%
import numpy as np

# %%
import matplotlib.pyplot as aa

# %%
# Compute the x and y coordinates for points on a sine curve 
x = np.arange(0, 6*np.pi, 0.1) 
y = np.sin(x) 
aa.plot(x, y) 
aa.title("sine wave formxxxxx") 
aa.show()

# %%
# Out:
# {'A': [1, 2]}
